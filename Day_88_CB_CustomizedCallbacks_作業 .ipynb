# %% [markdown]
# ## Work
# 1. 請嘗試寫一個 callback 用來記錄各類別在訓練過程中，對驗證集的 True Positive 與 True Negative
#
# ![image.png](attachment:image.png)

# %%
import os
import keras

from keras.datasets import cifar10
from keras.utils import np_utils

import warnings
warnings.filterwarnings('ignore')

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = np_utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization
def build_mlp(input_shape, output_units=10, num_neurons=[256, 256, 256]):
    """Code Here
    建立你的神經網路
    """
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 25
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
# 載入 Callbacks
from keras.callbacks import Callback

# Record_fp_tp
class Record_tp_tn(Callback):
    """Code Here
    撰寫一個紀錄 ture positive 與 true negative 數量的 callbacks    
    """
    def __init__(self, valid_data=(x_test, y_test)):
        self.validation_data = valid_data
        
    def on_train_begin(self, epoch, logs = {}):
        if 'metrics' not in self.params.keys():
            self.params['metrics'] = []
        print(f'self.params: {self.params}')
        logs = logs or {}
        record_items = ["val_tp", "val_tn"]
        for i in record_items:
            if i not in self.params['metrics']:
                self.params['metrics'].append(i)
    
    def on_epoch_end(self, epoch, logs = {}, thres=0.5):
        logs = logs or {}
        y_true = self.validation_data[1].argmax(axis = 1)
        y_pred = self.model.predict(self.validation_data[0])
        y_pred = (y_pred[:, 1] >= thres) * 1
        
        val_tp = sum(y_true * y_pred)
        val_tn = sum((y_true == 0) & (y_pred == 0))
        logs["val_tp"] = val_tp
        logs["val_tn"] = val_tn   
        
rec_tptn = Record_tp_tn()

# %%
from tensorflow.keras import optimizers

model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

"""Code Here
將 callbacks 放入模型訓練流程中
"""

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[rec_tptn]
         )

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

"""Code Here
將 tp/tn 從訓練完的模型中取出
"""
valid_tp = model.history.history['val_tp']
valid_tn = model.history.history['val_tn']
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 256)               786688
#
#  batch_normalization (BatchN  (None, 256)              1024
#  ormalization)
#
#  hidden_layer2 (Dense)       (None, 256)               65792
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  hidden_layer3 (Dense)       (None, 256)               65792
#
#  batch_normalization_2 (Batc  (None, 256)              1024
#  hNormalization)
#
#  output (Dense)              (None, 10)                2570
#
# =================================================================
# Total params: 923,914
# Trainable params: 922,378
# Non-trainable params: 1,536
# _________________________________________________________________
# self.params: {'verbose': 1, 'epochs': 25, 'steps': 49, 'metrics': []}
# Epoch 1/25
# 49/49 [==============================] - 4s 69ms/step - loss: 2.2634 - accuracy: 0.2627 - val_loss: 2.1560 - val_accuracy: 0.2364 - val_tp: 0.0000e+00 - val_tn: 1000.0000
# Epoch 2/25
# 49/49 [==============================] - 3s 57ms/step - loss: 1.7807 - accuracy: 0.3836 - val_loss: 1.9905 - val_accuracy: 0.3121 - val_tp: 0.0000e+00 - val_tn: 1000.0000
# Epoch 3/25
# 49/49 [==============================] - 3s 62ms/step - loss: 1.6431 - accuracy: 0.4266 - val_loss: 1.8534 - val_accuracy: 0.3614 - val_tp: 0.0000e+00 - val_tn: 1000.0000
# Epoch 4/25
# 49/49 [==============================] - 3s 59ms/step - loss: 1.5636 - accuracy: 0.4514 - val_loss: 1.7319 - val_accuracy: 0.4058 - val_tp: 23.0000 - val_tn: 1000.0000
# Epoch 5/25
# 49/49 [==============================] - 3s 64ms/step - loss: 1.5099 - accuracy: 0.4719 - val_loss: 1.6372 - val_accuracy: 0.4296 - val_tp: 164.0000 - val_tn: 999.0000
# Epoch 6/25
# 49/49 [==============================] - 3s 64ms/step - loss: 1.4637 - accuracy: 0.4867 - val_loss: 1.5782 - val_accuracy: 0.4479 - val_tp: 572.0000 - val_tn: 995.0000
# Epoch 7/25
# 49/49 [==============================] - 3s 59ms/step - loss: 1.4275 - accuracy: 0.4997 - val_loss: 1.5450 - val_accuracy: 0.4560 - val_tp: 861.0000 - val_tn: 993.0000
# Epoch 8/25
# 49/49 [==============================] - 3s 59ms/step - loss: 1.3910 - accuracy: 0.5109 - val_loss: 1.5212 - val_accuracy: 0.4666 - val_tp: 1248.0000 - val_tn: 988.0000
# Epoch 9/25
# 49/49 [==============================] - 3s 57ms/step - loss: 1.3608 - accuracy: 0.5230 - val_loss: 1.5077 - val_accuracy: 0.4646 - val_tp: 1628.0000 - val_tn: 983.0000
# Epoch 10/25
# 49/49 [==============================] - 3s 59ms/step - loss: 1.3341 - accuracy: 0.5325 - val_loss: 1.5030 - val_accuracy: 0.4715 - val_tp: 1097.0000 - val_tn: 991.0000
# Epoch 11/25
# 49/49 [==============================] - 3s 63ms/step - loss: 1.3092 - accuracy: 0.5430 - val_loss: 1.5021 - val_accuracy: 0.4704 - val_tp: 2154.0000 - val_tn: 975.0000
# Epoch 12/25
# 49/49 [==============================] - 3s 66ms/step - loss: 1.2859 - accuracy: 0.5521 - val_loss: 1.4767 - val_accuracy: 0.4798 - val_tp: 1580.0000 - val_tn: 984.0000
# Epoch 13/25
# 49/49 [==============================] - 3s 65ms/step - loss: 1.2623 - accuracy: 0.5608 - val_loss: 1.4814 - val_accuracy: 0.4815 - val_tp: 1958.0000 - val_tn: 975.0000
# Epoch 14/25
# 49/49 [==============================] - 3s 71ms/step - loss: 1.2416 - accuracy: 0.5691 - val_loss: 1.4691 - val_accuracy: 0.4857 - val_tp: 1607.0000 - val_tn: 985.0000
# Epoch 15/25
# 49/49 [==============================] - 3s 60ms/step - loss: 1.2207 - accuracy: 0.5791 - val_loss: 1.4620 - val_accuracy: 0.4895 - val_tp: 1851.0000 - val_tn: 982.0000
# Epoch 16/25
# 49/49 [==============================] - 3s 60ms/step - loss: 1.2014 - accuracy: 0.5840 - val_loss: 1.4719 - val_accuracy: 0.4841 - val_tp: 1851.0000 - val_tn: 977.0000
# Epoch 17/25
# 49/49 [==============================] - 3s 60ms/step - loss: 1.1811 - accuracy: 0.5931 - val_loss: 1.4673 - val_accuracy: 0.4854 - val_tp: 2546.0000 - val_tn: 976.0000
# Epoch 18/25
# 49/49 [==============================] - 3s 60ms/step - loss: 1.1636 - accuracy: 0.5996 - val_loss: 1.4574 - val_accuracy: 0.4871 - val_tp: 2413.0000 - val_tn: 975.0000
# Epoch 19/25
# 49/49 [==============================] - 3s 59ms/step - loss: 1.1456 - accuracy: 0.6047 - val_loss: 1.4604 - val_accuracy: 0.4871 - val_tp: 2147.0000 - val_tn: 971.0000
# Epoch 20/25
# 49/49 [==============================] - 3s 58ms/step - loss: 1.1274 - accuracy: 0.6138 - val_loss: 1.4567 - val_accuracy: 0.4897 - val_tp: 2776.0000 - val_tn: 969.0000
# Epoch 21/25
# 49/49 [==============================] - 3s 66ms/step - loss: 1.1103 - accuracy: 0.6193 - val_loss: 1.4453 - val_accuracy: 0.4946 - val_tp: 2191.0000 - val_tn: 977.0000
# Epoch 22/25
# 49/49 [==============================] - 3s 61ms/step - loss: 1.0932 - accuracy: 0.6245 - val_loss: 1.4426 - val_accuracy: 0.4952 - val_tp: 2173.0000 - val_tn: 976.0000
# Epoch 23/25
# 49/49 [==============================] - 3s 63ms/step - loss: 1.0775 - accuracy: 0.6322 - val_loss: 1.4520 - val_accuracy: 0.4932 - val_tp: 1944.0000 - val_tn: 979.0000
# Epoch 24/25
# 49/49 [==============================] - 3s 61ms/step - loss: 1.0601 - accuracy: 0.6387 - val_loss: 1.4358 - val_accuracy: 0.4971 - val_tp: 1974.0000 - val_tn: 982.0000
# Epoch 25/25
# 49/49 [==============================] - 3s 63ms/step - loss: 1.0439 - accuracy: 0.6443 - val_loss: 1.4333 - val_accuracy: 0.5064 - val_tp: 1995.0000 - val_tn: 979.0000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

plt.plot(range(len(valid_tp)), valid_tp, label="valid tp", color="navy")
plt.plot(range(len(valid_tn)), valid_tn, label="valid tn", color="red")
plt.legend()
plt.title("True positives and True Negatives")
plt.show()
